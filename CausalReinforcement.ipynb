# %%
def R(h,n,a,d):
    #(h/2.0+a/(a-2.0))*d 
    return  4*a*log(n)*exp(-2*h*pow(.5-2*a*log(n)/(h*pow(d,2)),2))/float(d)

T = 10
a = 4
d = 0.001

r = []
for h in range(1,T):
    n = T-h
    r.append(R(h,n,a,d))
plot(range(1,T),r)
show()

# %%
exp(1)
# Out:
# 2.7182818284590451

# %%
# what about weighted sums of bernoulli random variables...

from scipy.stats import bernoulli

x = [0,1]
y = bernoulli.pmf(x,.2)

fig, axis = subplots()
bar(x,y,align='center')
xticks(x, ('1', '0'))
show()

y2 = bernoulli.pmf(x,.55)

w = .3

# %%
bar?

# %%
# playing around with properties of the beta distribution
from scipy.stats import beta

x = linspace(0,1,100)
y = beta.pdf(x,3,10)
plot(x,y)
show()

y2 = beta.pdf(x,15,5)
plot(x,y2)
show()

w = .2
y3 = w*y+(1-w)*y2
plot(x,y3)
show()

# %% [markdown]
# TODO Explain the general setting
#
# TODO Explain the key to causal reinforcement learning
#
# I want to compare how adding causal information changes things as I add variables. Simulating data using a full probability model becomes computationally expensive as the number of variables $N$ increases since the size of the table $P(y=1|x_{1}...x_{N})$ is $2^{N}$.
#
# So instead I am simulating data using a logistic model, $P(y=1|x_{1}...x_{N}) = sigmoid(\theta_{0}+\theta_{1}x_{1}+...+\theta_{N}x_{N})$, which has $N+1$ parameters. In order to calculate the regret, I need to estimate the marginal probabilities correponding to each possible intervention, ie $P(y=1|x_{1}=0),P(y=1|x_{1}=1)...P(y=1|x_{N}=1)$ Finding these probabilities exactly still requires summing over $2^N$ terms, so instead I approximate them with monte-carlo sampling.
#
# TODO Explain why I chose the parameters I did

# %%
# %install_ext http://www.ipp.mpg.de/~mkraus/python/tikzmagic.py
# %load_ext tikzmagic
# Out:
# Installed tikzmagic.py. To use it, type:
#   %load_ext tikzmagic

# %%
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-4-445a5d6380b0> in <module>()
# ----> 1 get_ipython().magic(u'load_ext tikzmagic')
#
# /usr/local/lib/python2.7/dist-packages/ipython-1.1.0-py2.7.egg/IPython/core/interactiveshell.pyc in magic(self, arg_s)
#    2170         magic_name, _, magic_arg_s = arg_s.partition(' ')
#    2171         magic_name = magic_name.lstrip(prefilter.ESC_MAGIC)
# -> 2172         return self.run_line_magic(magic_name, magic_arg_s)
#    2173
#    2174     #-------------------------------------------------------------------------
#
# /usr/local/lib/python2.7/dist-packages/ipython-1.1.0-py2.7.egg/IPython/core/interactiveshell.pyc in run_line_magic(self, magic_name, line)
#    2091                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2092             with self.builtin_trap:
# -> 2093                 result = fn(*args,**kwargs)
#    2094             return result
#    2095
#
# /usr/local/lib/python2.7/dist-packages/ipython-1.1.0-py2.7.egg/IPython/core/magics/extension.pyc in load_ext(self, module_str)
#
# /usr/local/lib/python2.7/dist-packages/ipython-1.1.0-py2.7.egg/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     189     # but it's overkill for just that one bit of state.
#     190     def magic_deco(arg):
# --> 191         call = lambda f, *a, **k: f(*a, **k)
#     192
#     193         if callable(arg):
#
# /usr/local/lib/python2.7/dist-packages/ipython-1.1.0-py2.7.egg/IPython/core/magics/extension.pyc in load_ext(self, module_str)
#      60         if not module_str:
#      61             raise UsageError('Missing module name.')
# ---> 62         res = self.shell.extension_manager.load_extension(module_str)
#      63
#      64         if res == 'already loaded':
#
# /usr/local/lib/python2.7/dist-packages/ipython-1.1.0-py2.7.egg/IPython/core/extensions.pyc in load_extension(self, module_str)
#      96             if module_str not in sys.modules:
#      97                 with prepended_to_syspath(self.ipython_extension_dir):
# ---> 98                     __import__(module_str)
#      99             mod = sys.modules[module_str]
#     100             if self._call_load_ipython_extension(mod):
#
# ImportError: No module named tikzmagic

# %%
from multicausesim import *
from scipy.stats import bernoulli 
import matplotlib.pyplot as plt

o = open("causalreinforce5.txt","w")
experiments = 100
timesteps = 100
for k in xrange(3,20):
    w = zeros(k)
    w[0] = 1
    for i in xrange(experiments): # make this many models for each arm
        model = LogisticProbabilityModel([0.5]*k,w,w0=-1,m=1000)
        bandit = CausalBinaryBandit(model)
        ucbRegret = bandit.UCBSample(timesteps,0.05)
        result = ",".join([str(x) for x in [k,i,ucbRegret,"ucb"]])+"\n"
        o.write(result)
        bandit.reset()
        causalRegret = bandit.causalThompsonSample(timesteps,0.05)
        result = ",".join([str(x) for x in [k,i,causalRegret,"causal"]])+"\n"
        o.write(result)
    o.flush()

# %%
# lets read in data
import pandas as pd
data = pd.read_csv("causalreinforce4.txt",names=["K","i","regret","ts","algorithm"])
data2 = data.groupby([data.K,data.algorithm])

means = data2.mean()
sds = data2.agg(np.std)['regret']

causal = means.iloc[0:means.shape[0]:2,2]
ucb = means.iloc[1:means.shape[0]:2]
x = ucb.iloc[:,0]
ucb = ucb.iloc[:,2]
causalsd = sds.iloc[0:means.shape[0]:2]
ucbsd = sds.iloc[1:means.shape[0]:2]

fig,ax = subplots()
ax.errorbar(x+0.05,ucb,yerr=ucbsd,fmt="o",label="ucb")
ax.errorbar(x-0.05,causal,yerr=causalsd,fmt="D",label="causal")
ax.set_ylabel("regret")
ax.set_xlabel("arms")
ax.legend(loc="lower right",numpoints=1)
show()

# %%
TODO explain what seems expected and what is odd about these results.

# %%
x = linspace(1,99,100)
y = (x*(100-x)/100)
fig,ax = subplots()
ax.plot(x,y)
show()
